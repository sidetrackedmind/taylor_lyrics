# %% [markdown]
# # Issue
# Issue with evermore - long story short. It downloads tour dates?

# %%
from lyricsgenius import Genius
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv
import os
import pandas as pd
import glob

# %%
load_dotenv()
# Out:
# True

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=os.environ['spotify_client_id'],
                                                           client_secret=os.environ['spotify_client_secret']))

# %%
results = sp.search(q='Taylor Swift', limit=1, type='artist')

# %%
taylors_spotify_id = results['artists']['items'][0]['id']

# %%
taylors_spotify_id
# Out:
# '06HL4z0CvFAxyc27GXpf02'

# %%
list(range(0,100,50))
# Out:
# [0, 50]

# %%
taylor_albums_pt1 = sp.artist_albums(artist_id=taylors_spotify_id, album_type='album', limit=50, offset=0)
taylor_albums_pt2 = sp.artist_albums(artist_id=taylors_spotify_id, album_type='album', limit=50, offset=50)

# %%
all_taylor_albums = taylor_albums_pt2['items']+taylor_albums_pt1['items']
all_taylor_albums_df = pd.DataFrame(all_taylor_albums)
all_taylor_albums_df.head(3)
# Out:
#   album_group album_type                                            artists  \
# 0       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 1       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 2       album      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  \
# 0                                           [AU, NZ]
# 1  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 2                                               [JP]
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/6G...
# 1  {'spotify': 'https://open.spotify.com/album/6S...
# 2  {'spotify': 'https://open.spotify.com/album/3M...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/albums/6GPyXXND6hIZ...  6GPyXXND6hIZpd9bRhCsFv
# 1  https://api.spotify.com/v1/albums/6S6JQWzUrJVc...  6S6JQWzUrJVcJLK4fi74Fw
# 2  https://api.spotify.com/v1/albums/3Mvk2LKxfhc2...  3Mvk2LKxfhc2KVSnDYC40I
#
#                                               images  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                          name release_date release_date_precision  \
# 0      Speak Now (US Version)   2010-01-01                    day
# 1  Speak Now (Deluxe Package)   2010-01-01                    day
# 2                    Fearless   2008-11-11                    day
#
#    total_tracks   type                                   uri
# 0            14  album  spotify:album:6GPyXXND6hIZpd9bRhCsFv
# 1            22  album  spotify:album:6S6JQWzUrJVcJLK4fi74Fw
# 2            20  album  spotify:album:3Mvk2LKxfhc2KVSnDYC40I

# %% [markdown]
# ### Get rid of all the special albums
# If you're a hardcore fan you may not like this
# > Haters gonna hate

# %%
normal_albums = [album_name for album_name in all_taylor_albums_df['name'].unique() if ('version' not in album_name.lower()) 
and ('deluxe' not in album_name.lower()) and ('karaoke' not in album_name.lower()) and ('edition' not in album_name.lower())
and ('special' not in album_name.lower()) and ('tour' not in album_name.lower()) and ('live' not in album_name.lower())]
normal_albums
# Out:
# ['Fearless',
#  'Taylor Swift',
#  'Midnights',
#  'evermore',
#  'folklore',
#  'Lover',
#  'reputation',
#  '1989',
#  'Red',
#  'Speak Now']

# %%
filtered_albums_df = all_taylor_albums_df[all_taylor_albums_df['name'].isin(normal_albums)].copy()
filtered_albums_df.head()
# Out:
#    album_group album_type                                            artists  \
# 2        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 3        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 5        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 12       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 13       album      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  \
# 2                                                [JP]
# 3                            [BE, CH, DE, ES, GR, SE]
# 5                                            [CA, US]
# 12                                               [CA]
# 13  [AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB, B...
#
#                                         external_urls  \
# 2   {'spotify': 'https://open.spotify.com/album/3M...
# 3   {'spotify': 'https://open.spotify.com/album/6t...
# 5   {'spotify': 'https://open.spotify.com/album/2d...
# 12  {'spotify': 'https://open.spotify.com/album/1r...
# 13  {'spotify': 'https://open.spotify.com/album/5e...
#
#                                                  href                      id  \
# 2   https://api.spotify.com/v1/albums/3Mvk2LKxfhc2...  3Mvk2LKxfhc2KVSnDYC40I
# 3   https://api.spotify.com/v1/albums/6tgMb6LEwb3y...  6tgMb6LEwb3yj7BdYy462y
# 5   https://api.spotify.com/v1/albums/2dqn5yOQWdyG...  2dqn5yOQWdyGwOpOIi9O4x
# 12  https://api.spotify.com/v1/albums/1rwH2628RIOV...  1rwH2628RIOVM3WMwwO418
# 13  https://api.spotify.com/v1/albums/5eyZZoQEFQWR...  5eyZZoQEFQWRHkV2xgAeBw
#
#                                                images          name  \
# 2   [{'height': 640, 'url': 'https://i.scdn.co/ima...      Fearless
# 3   [{'height': 640, 'url': 'https://i.scdn.co/ima...      Fearless
# 5   [{'height': 640, 'url': 'https://i.scdn.co/ima...      Fearless
# 12  [{'height': 640, 'url': 'https://i.scdn.co/ima...      Fearless
# 13  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Taylor Swift
#
#    release_date release_date_precision  total_tracks   type  \
# 2    2008-11-11                    day            20  album
# 3    2008-11-11                    day            17  album
# 5    2008-11-11                    day            13  album
# 12   2008-01-01                    day            13  album
# 13   2006-10-24                    day            15  album
#
#                                      uri
# 2   spotify:album:3Mvk2LKxfhc2KVSnDYC40I
# 3   spotify:album:6tgMb6LEwb3yj7BdYy462y
# 5   spotify:album:2dqn5yOQWdyGwOpOIi9O4x
# 12  spotify:album:1rwH2628RIOVM3WMwwO418
# 13  spotify:album:5eyZZoQEFQWRHkV2xgAeBw

# %% [markdown]
# ### Ugh still multiple albums
# If duplicates, rank but number of tracks and take one row per album name

# %%
filtered_albums_df['album_rank'] = filtered_albums_df.groupby('name')['total_tracks'].rank(method='first', ascending=False)

# %%
top_filtered_albums = filtered_albums_df[filtered_albums_df['album_rank']==1].copy()
top_filtered_albums
# Out:
#    album_group album_type                                            artists  \
# 2        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 13       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 20       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 27       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 34       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 36       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 38       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 42       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 56       album      album  [{'external_urls': {'spotify': 'https://open.s...
# 62       album      album  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  \
# 2                                                [JP]
# 13  [AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB, B...
# 20  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 27  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 34  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 36  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 38  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 42                                               [JP]
# 56  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...
# 62                                           [CA, US]
#
#                                         external_urls  \
# 2   {'spotify': 'https://open.spotify.com/album/3M...
# 13  {'spotify': 'https://open.spotify.com/album/5e...
# 20  {'spotify': 'https://open.spotify.com/album/15...
# 27  {'spotify': 'https://open.spotify.com/album/2X...
# 34  {'spotify': 'https://open.spotify.com/album/2f...
# 36  {'spotify': 'https://open.spotify.com/album/1N...
# 38  {'spotify': 'https://open.spotify.com/album/6D...
# 42  {'spotify': 'https://open.spotify.com/album/4u...
# 56  {'spotify': 'https://open.spotify.com/album/7d...
# 62  {'spotify': 'https://open.spotify.com/album/5M...
#
#                                                  href                      id  \
# 2   https://api.spotify.com/v1/albums/3Mvk2LKxfhc2...  3Mvk2LKxfhc2KVSnDYC40I
# 13  https://api.spotify.com/v1/albums/5eyZZoQEFQWR...  5eyZZoQEFQWRHkV2xgAeBw
# 20  https://api.spotify.com/v1/albums/151w1FgRZfnK...  151w1FgRZfnKZA9FEcg9Z3
# 27  https://api.spotify.com/v1/albums/2Xoteh7uEpea...  2Xoteh7uEpea4TohMxjtaq
# 34  https://api.spotify.com/v1/albums/2fenSS68JI1h...  2fenSS68JI1h4Fo296JfGr
# 36  https://api.spotify.com/v1/albums/1NAmidJlEaVg...  1NAmidJlEaVgA3MpcPFYGq
# 38  https://api.spotify.com/v1/albums/6DEjYFkNZh67...  6DEjYFkNZh67HP7R9PSZvv
# 42  https://api.spotify.com/v1/albums/4uUAUqIfSomF...  4uUAUqIfSomFTbbjGp3TYp
# 56  https://api.spotify.com/v1/albums/7daMnnffzVSb...  7daMnnffzVSbNJj8Dy75Ev
# 62  https://api.spotify.com/v1/albums/5MfAxS5zz8Ml...  5MfAxS5zz8MlfROjGQVXhy
#
#                                                images          name  \
# 2   [{'height': 640, 'url': 'https://i.scdn.co/ima...      Fearless
# 13  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Taylor Swift
# 20  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Midnights
# 27  [{'height': 640, 'url': 'https://i.scdn.co/ima...      evermore
# 34  [{'height': 640, 'url': 'https://i.scdn.co/ima...      folklore
# 36  [{'height': 640, 'url': 'https://i.scdn.co/ima...         Lover
# 38  [{'height': 640, 'url': 'https://i.scdn.co/ima...    reputation
# 42  [{'height': 640, 'url': 'https://i.scdn.co/ima...          1989
# 56  [{'height': 640, 'url': 'https://i.scdn.co/ima...           Red
# 62  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Speak Now
#
#    release_date release_date_precision  total_tracks   type  \
# 2    2008-11-11                    day            20  album
# 13   2006-10-24                    day            15  album
# 20   2022-10-21                    day            13  album
# 27   2020-12-11                    day            15  album
# 34   2020-07-24                    day            16  album
# 36   2019-08-23                    day            18  album
# 38   2017-11-10                    day            15  album
# 42   2014-10-27                    day            13  album
# 56   2012-10-22                    day            16  album
# 62   2010-10-25                    day            14  album
#
#                                      uri  album_rank
# 2   spotify:album:3Mvk2LKxfhc2KVSnDYC40I         1.0
# 13  spotify:album:5eyZZoQEFQWRHkV2xgAeBw         1.0
# 20  spotify:album:151w1FgRZfnKZA9FEcg9Z3         1.0
# 27  spotify:album:2Xoteh7uEpea4TohMxjtaq         1.0
# 34  spotify:album:2fenSS68JI1h4Fo296JfGr         1.0
# 36  spotify:album:1NAmidJlEaVgA3MpcPFYGq         1.0
# 38  spotify:album:6DEjYFkNZh67HP7R9PSZvv         1.0
# 42  spotify:album:4uUAUqIfSomFTbbjGp3TYp         1.0
# 56  spotify:album:7daMnnffzVSbNJj8Dy75Ev         1.0
# 62  spotify:album:5MfAxS5zz8MlfROjGQVXhy         1.0

# %%
top_filtered_albums.to_csv("taylor_swift_top_filtered_albums.csv", index=False)

# %% [markdown]
# ### Okay now we can grab the track names!

# %%
album_df_list = []
for idx, row in top_filtered_albums.iterrows():
    album_name = row['name']
    album_id = row['id']
    album_tracks = sp.album_tracks(album_id=album_id)
    album_df = pd.DataFrame(album_tracks['items'])
    album_df['album_name'] = album_name
    album_df_list.append(album_df)

# %%
all_albums_with_tracks = pd.concat(album_df_list)
all_albums_with_tracks.head(3)
# Out:
#                                              artists available_markets  \
# 0  [{'external_urls': {'spotify': 'https://open.s...              [JP]
# 1  [{'external_urls': {'spotify': 'https://open.s...              [JP]
# 2  [{'external_urls': {'spotify': 'https://open.s...              [JP]
#
#    disc_number  duration_ms  explicit  \
# 0            1       242826     False
# 1            1       294880     False
# 2            1       234213     False
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/2g...
# 1  {'spotify': 'https://open.spotify.com/track/6Z...
# 2  {'spotify': 'https://open.spotify.com/track/6S...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/2gtEqWfjIa9j...  2gtEqWfjIa9j4qfsHcDVl5
# 1  https://api.spotify.com/v1/tracks/6ZeKYXZ6esPj...  6ZeKYXZ6esPjpuHwCtUiZh
# 2  https://api.spotify.com/v1/tracks/6SgBWLgjMQdo...  6SgBWLgjMQdoVQytBgATGx
#
#    is_local        name preview_url  track_number   type  \
# 0     False    Fearless        None             1  track
# 1     False     Fifteen        None             2  track
# 2     False  Love Story        None             3  track
#
#                                     uri album_name
# 0  spotify:track:2gtEqWfjIa9j4qfsHcDVl5   Fearless
# 1  spotify:track:6ZeKYXZ6esPjpuHwCtUiZh   Fearless
# 2  spotify:track:6SgBWLgjMQdoVQytBgATGx   Fearless

# %%
all_albums_with_tracks.shape
# Out:
# (155, 15)

# %%
all_albums_with_tracks.to_csv('taylor_swift_albums_with_tracks.csv', index=False)

# %%
genius = Genius(access_token=os.environ['genius_client_access_token'])

# %%
artist = genius.search_artist("Taylor Swift", max_songs=1, sort="title")
# Out:
# Searching for songs by Taylor Swift...
#
# "1989 [Booklet]" is not valid. Skipping.
# "1989 Interview with Paul McGuire" is not valid. Skipping.
# "1989 [Liner Notes]" is not valid. Skipping.
# "1989 Tour Setlist" is not valid. Skipping.
# Song 1: "1989 World Tour Costumes"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.

# %%
for idx, row in all_albums_with_tracks.iterrows():
    album_name = row['album_name']
    song_name = row['name']
    #skip karaoke versions of songs and skip long story short because genius' API has a glitch
    #for the lyrics for that song
    if ('karaoke' not in song_name.lower()) and ('long story short' not in song_name.lower()):
        genuis_song_record = artist.song(song_name)
        if genuis_song_record is not None:
            with open(f'lyric_files/{album_name}-{song_name}.txt', 'w') as f:
                f.write(genuis_song_record.lyrics)
# Out:
# Searching for "...Ready For It?" by Taylor Swift...
# Done.
# Searching for "End Game" by Taylor Swift...
# Done.
# Searching for "I Did Something Bad" by Taylor Swift...
# Done.
# Searching for "Don’t Blame Me" by Taylor Swift...
# Done.
# Searching for "Delicate" by Taylor Swift...
# Done.
# Searching for "Look What You Made Me Do" by Taylor Swift...
# Done.
# Searching for "So It Goes..." by Taylor Swift...
# Done.
# Searching for "Gorgeous" by Taylor Swift...
# Done.
# Searching for "Getaway Car" by Taylor Swift...
# Done.
# Searching for "King Of My Heart" by Taylor Swift...
# Done.
# Searching for "Dancing With Our Hands Tied" by Taylor Swift...
# Done.
# Searching for "Dress" by Taylor Swift...
# Done.
# Searching for "This Is Why We Can't Have Nice Things" by Taylor Swift...
# Done.
# Searching for "Call It What You Want" by Taylor Swift...
# Done.
# Searching for "New Year’s Day" by Taylor Swift...
# Done.
# Searching for "Welcome To New York" by Taylor Swift...
# Done.
# Searching for "Blank Space" by Taylor Swift...
# Done.
# Searching for "Style" by Taylor Swift...
# Done.
# Searching for "Out Of The Woods" by Taylor Swift...
# Done.
# Searching for "All You Had To Do Was Stay" by Taylor Swift...
# Done.
# Searching for "Shake It Off" by Taylor Swift...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1129 if buffer is not None:
# -> 1130     return self._sslobj.read(len, buffer)
#    1131 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/lyricsgenius/api/base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/requests/adapters.py:578, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     577 elif isinstance(e, ReadTimeoutError):
# --> 578     raise ReadTimeout(e, request=request)
#     579 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# Cell In [107], line 4
#       2 album_name = row['album_name']
#       3 song_name = row['name']
# ----> 4 genuis_song_record = genius.search_song(song_name, "Taylor Swift")
#       5 with open(f'lyric_files/{album_name}-{song_name}.txt', 'w') as f:
#       6     f.write(genuis_song_record.lyrics)
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/lyricsgenius/genius.py:436, in Genius.search_song(self, title, artist, song_id, get_full_info)
#     432     song_info.update(new_info)
#     434 if (song_info['lyrics_state'] == 'complete'
#     435         and not song_info.get('instrumental')):
# --> 436     lyrics = self.lyrics(song_url=song_info['url'])
#     437 else:
#     438     lyrics = ""
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/lyricsgenius/genius.py:132, in Genius.lyrics(self, song_id, song_url, remove_section_headers)
#     128     path = self.song(song_id)['song']['path'][1:]
#     130 # Scrape the song lyrics from the HTML
#     131 html = BeautifulSoup(
# --> 132     self._make_request(path, web=True).replace('<br/>', '\n'),
#     133     "html.parser"
#     134 )
#     136 # Determine the class of the div
#     137 div = html.find("div", class_=re.compile("^lyrics$|Lyrics__Root"))
#
# File ~/opt/anaconda3/envs/taylor-lyrics/lib/python3.10/site-packages/lyricsgenius/api/base.py:84, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      82     error = "Request timed out:\n{e}".format(e=e)
#      83     if tries > self.retries:
# ---> 84         raise Timeout(error)
#      85 except HTTPError as e:
#      86     error = get_description(e)
#
# Timeout: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)

# %% [markdown]
# ### If timeout of failure
# Run the following cells to get the downloaded songs, join back with the original and see what's left to download. This could be more graceful but it works for now.

# %%
lyric_file_list = glob.glob('lyric_files/*.txt')

# %%
downloaded_songs = pd.DataFrame([(file_name.split('/')[-1].split('.txt')[0].split('-')[0]
,'-'.join(file_name.split('/')[-1].split('.txt')[0].split('-')[1:])) for file_name in lyric_file_list]
,columns=['album_name','name'])
downloaded_songs['is_downloaded'] = 1
downloaded_songs.head(3)
# Out:
#   album_name         name  is_downloaded
# 0   Fearless  Tell Me Why              1
# 1   folklore         hoax              1
# 2   folklore        the 1              1

# %%
all_album_compare_with_downloaded = all_albums_with_tracks.merge(downloaded_songs, how='left', on=['album_name','name'])

# %%
still_need_album_tracks = all_album_compare_with_downloaded[(all_album_compare_with_downloaded['is_downloaded'].isna())].copy()
still_need_album_tracks.head(3)
# Out:
#                                                artists  \
# 59   [{'external_urls': {'spotify': 'https://open.s...
# 126  [{'external_urls': {'spotify': 'https://open.s...
# 127  [{'external_urls': {'spotify': 'https://open.s...
#
#                                      available_markets  disc_number  \
# 59   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 126  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 127  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#      duration_ms  explicit                                      external_urls  \
# 59        215920     False  {'spotify': 'https://open.spotify.com/track/2o...
# 126       223698     False  {'spotify': 'https://open.spotify.com/track/2t...
# 127       243643     False  {'spotify': 'https://open.spotify.com/track/28...
#
#                                                   href  \
# 59   https://api.spotify.com/v1/tracks/2o2sgVJIgFXk...
# 126  https://api.spotify.com/v1/tracks/2tYdjm4wmx4L...
# 127  https://api.spotify.com/v1/tracks/28d5SkpM2XwX...
#
#                          id  is_local                           name  \
# 59   2o2sgVJIgFXk8GQjWTgI6U     False               long story short
# 126  2tYdjm4wmx4LaxihipeFXC     False          Red - Karaoke Version
# 127  28d5SkpM2XwX3iDrOJE9JZ     False  Treacherous - Karaoke Version
#
#     preview_url  track_number   type                                   uri  \
# 59         None            12  track  spotify:track:2o2sgVJIgFXk8GQjWTgI6U
# 126        None             2  track  spotify:track:2tYdjm4wmx4LaxihipeFXC
# 127        None             3  track  spotify:track:28d5SkpM2XwX3iDrOJE9JZ
#
#     album_name  is_downloaded
# 59    evermore            NaN
# 126        Red            NaN
# 127        Red            NaN

# %%
for idx, row in still_need_album_tracks.iterrows():
    album_name = row['album_name']
    song_name = row['name']
    if 'karaoke' not in song_name.lower():
        genuis_song_record = artist.song(song_name)
        if genuis_song_record is not None:
            with open(f'lyric_files/{album_name}-{song_name}.txt', 'w') as f:
                f.write(genuis_song_record.lyrics)
# Out:
# Searching for "long story short" by Taylor Swift...
# Done.
